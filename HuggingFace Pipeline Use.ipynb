# %% [markdown]
# # HuggingFace Pipeline Use
#
#
# 1. 주제를 선정한다.
# 2. 사전 학습(또는 전이 학습된) 모델을 HuggingFace로부터 Pipeline을 이용해 로드해 온다.
# 3. 내가 원하는 주제에 부합하는 시스템이 동작하도록 한다.
# - console 에서 진행 OK
# - streamlit 구현 OK

# %%
# !pip install transformers torch streamlit

# %%
from transformers import pipeline

generator = pipeline("text-generation", model="gpt2")

print(generator("AI is", max_length=30))
# Out:
# Loading weights: 100%|██████████| 148/148 [00:00<00:00, 6913.12it/s]
# Setting `pad_token_id` to `eos_token_id`:50256 for open-end generation.
# Both `max_new_tokens` (=256) and `max_length`(=30) seem to have been set. `max_new_tokens` will take precedence. Please refer to the documentation for more information. (https://huggingface.co/docs/transformers/main/en/main_classes/text_generation)
# [{'generated_text': 'AI is not aware of any significant differences and will not comment on the status of any such relationships.\n\nThere are no other data sets available for this specific case.\n\nThe following is a summary of the information available to the IPCC and the relevant authorities. For further information, please refer to the following:\n\nhttp://www.epa.gov/climate/global/the-evidence/dietary-data/climate-policy\n\nhttp://www.epa.gov/climate/global/the-evidence/dietary-data/climate-policy/climate-data-on-world-warming\n\nThe IPCC\'s global warming predictions are based on a "natural variability" methodology, which is based on the uncertainty of the natural variability of the Earth\'s surface weather and climate. The following are the data that are provided in this report.\n\nWarming in the West\n\nThe annual average annual temperature of the world\'s oceans, in the last decade, has been warming by 0.6°C and the global mean global temperature has been 0.3°C for the past 30 years.\n\nThe "end-of-the-century" warming trend for the last 30 years has been 0.4°C and'}]

# %%
import streamlit as st
from transformers import pipeline

st.title("🩺 AI Medical Symptom Checker")

st.cache_resource
def load_model():
    return pipeline(
        "text-generation",
        model="google/flan-t5-small"
    )

generator = load_model()

symptom = st.text_input("Enter your symptom (example: headache, fever)")

if st.button("Analyze Symptom"):

    if symptom == "":
        st.warning("Please enter a symptom")

    else:

        prompt = f"""
        A patient has this symptom: {symptom}.
        List 5 possible diseases.
        """

        result = generator(prompt, max_new_tokens=50)

        st.subheader("Possible illnesses")
        st.write(result[0]["generated_text"])

        st.info("This AI is for educational purposes only.")
# Out:
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.688 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.700 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.
# 2026-03-15 15:46:08.702 Thread 'MainThread': missing ScriptRunContext! This warning can be ignored when running in bare mode.

# %%
import tiktoken

gpt35 = tiktoken.encoding_for_model('gpt-3.5')
print(gpt35)
print(len(gpt.encode('오늘은 즐거운 월요일 입니다!')))
gpt40 = tiktoken.encoding_for_model('gpt-40')
print(gp40)
print(len(gpt.encode('오늘은 즐거운 월요일 입니다!')))
gpt51 = tiktoken.encoding_for_model('gpt-5')
print(gpt5)
print(len(gpt.encode('오늘은 즐거운 월요일 입니다!')))

# %%
model = 'gpt-5.2'

try:
    enc= tiktoken.encoding_for_model(model)
except KeyError as e :
    print(f
